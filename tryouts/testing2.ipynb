# %%
import re
import spacy
import json
from spacy.matcher import Matcher

nlp = spacy.load("en_core_web_sm")

# %%
ruler = nlp.add_pipe("entity_ruler", before="ner")

# Function to add custom rules based on the synonyms in JSON
def add_custom_rules():
    with open("OCR_raw_samples/X1.json", "r") as file:
        data = json.load(file)
        patterns = []
        for entry in data:
            for synonym in entry["Synonyms"]:
                patterns.append({"label": "TEST", "pattern": synonym})
        # print(patterns)
        ruler.add_patterns(patterns)

# Load custom rules
add_custom_rules()

# %%
# file_path = "OCR_raw_samples/0b8706dc-c9af-4c6b-887d-2f85b5a511e7.txt"
file_path = "OCR_raw_samples/0ab9800e-bc9a-4388-aaa2-d4fc05e7d111.txt"

with open(file_path, 'r') as file:
    # text = file.read()
    data = file.read().replace("\n", " ")
    # text = clean_text(text)
doc = nlp(data)

# %%
# Initialize a dictionary to store drug parameters, values, and units
drug_data = {}

for ent in doc.ents:
    if ent.label_ == "TEST":
        # Start a new entry for this parameter if it doesn't exist
        if ent.text not in drug_data:
            drug_data[ent.text] = {"values": [], "units": []}
        # Focus on this parameter for subsequent values and units
        current_parameter = ent.text

    elif ent.label_ == "CARDINAL" and "current_parameter" in locals():
        # Append value to the current parameter
        drug_data[current_parameter]["values"].append(ent.text)

    elif ent.label_ == "ORG" and "current_parameter" in locals():
        # Append unit to the current parameter
        drug_data[current_parameter]["units"].append(ent.text)

# To display the organized drug data
print(drug_data)
# Out:
# {'PRL': {'values': ['125', '125', '125', '18 10', '18', '125', '24/09/1932', '18 10', '18', '1.5-9.9', '8.3', '9.0', '125', '24/09/1932', '125', '24/09/1932', '7', '18 10', '18', '4.1', '3.4', '125', '24/09/1932', '19.9', '7', '18 10', '18', '6.0', '7.0', '125', '24/09/1932', '125', '125', '125', '7', '18 10', '18', '15', '13', '125', '24/09/1932', '125', '24/09/1932', '12', '18 10', '18', '125', '24/09/1932', '125', '24/09/1932', '17', '6.0', '4.0', '30', '125', '24/09/1932', '15.3', '7', '18 10', '18', '18', '125', '24/09/1932', '6', '125', '24/09/1932', '12', '18 10', '18', '125', '24/09/1932', '12', '18 10', '18', '125'], 'units': ['PTH', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FE, FBE', 'DVI', 'COR \x0c     Date Requested:', 'PTH', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FE, FBE', 'DVI', 'COR \x0c Patient Name', 'Medicare', 'SERUM CORTISOL', 'VBF', 'UMM', 'TAA', 'PTH', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FE, FBE', 'COR \x0c Patient Name', 'Patient Address', 'Medicare', 'prolactin  IRON STUDIES', 'PTH', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FE, FBE', 'COR* \x0c Patient Name', 'Patient Address', 'IHI No', 'VBF', 'UMM', 'TAA', 'PTH', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FBE', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FBE', 'COR* \x0c Patient Name', 'SERUM C.E.A', 'CEA', 'Bayer', 'CEA', 'CEA', 'CEA', 'VBF', 'UMM', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FBE', 'COR* \x0c Patient Name', 'Patient Address', 'IHI No', 'Bayer Centaur', 'VBF', 'UMM', 'ESR', 'CRP', 'CEA', 'C19', 'C15', 'FBE', 'COR* \x0c Patient Name', 'VBF', 'UMM', 'ESR', 'CRP', 'CEA', 'C15', 'FE* FBE', 'COR* \x0c Patient Name', 'ESR', 'CRP', 'CEA', 'C15', 'FE* FBE', 'COR* \x0c Patient Name', 'ESR', 'CRP', 'CEA', 'C15', 'FE* FBE', 'COR* \x0c Patient Name', 'IHI', 'SERUM PROLACTIN', 'PRL-0) Clinical Information', 'ESR', 'CRP', 'CEA', 'C15', 'FBE', 'COR*', 'Medicare', 'UMM', 'Laverty Pathology DR', 'ESR', 'CRP', 'CEA', 'Bayer Centaur', 'UMM', 'ESR', 'CEA', 'C15', 'FBE', 'COR* \x0c Patient Name', 'URINE MICRO/CULTURE', 'MICROSCOPY', 'ESR', 'CEA', 'FBE', 'COR* \x0c Patient Name', 'Patient Address', 'E.S.R (ESR-0) Clinical Information', 'ESR', 'ESR', 'CEA', 'FBE', 'COR* \x0c Patient Name', 'Patient Address', 'IHI No', 'FBE-0) Clinical Information', 'CEA', 'FBE', 'COR']}, 'Vitamin D': {'values': ['108', '25 - 50', '250', '196(11),686-687'], 'units': ['VBF', 'UMM', 'TAA']}, 'Iron': {'values': ['27'], 'units': []}, 'T': {'values': [], 'units': []}, 'T. Sat.': {'values': [], 'units': []}, 'Ferritin': {'values': ['30-400', '110', '115 44', 'between 50 and 100'], 'units': ['VBF', 'UMM', 'TAA']}, 'Anti-Thyroglobulin Abs': {'values': ['110'], 'units': ['TU']}, 'Anti-Thyroidal Peroxidase Abs': {'values': ['332'], 'units': ['U/mL (< 60']}, 'Tg': {'values': [], 'units': ['Graves', 'VBF', 'UMM', 'TAA']}, 'B12': {'values': ['7', '18 10', '18', '301-740', '860', '36', '128'], 'units': []}, 'Folate': {'values': ['23.1', '25.0', '33.6', '4.5 - 9.0', '340', '570', 'between 4.5 and 9.0'], 'units': ['SUFFICIENCY', 'pre nen enn nee pon--- +--+ $----------~-------+- $o-ee---------', 'Medicare', 'VBF', 'UMM']}, 'Na': {'values': ['135', '140', '142', '138'], 'units': []}, 'K': {'values': ['3.6-5.4', '4.0', '3.8'], 'units': []}, 'Cl': {'values': ['95', '108', '101', '10-20'], 'units': []}, 'Urea': {'values': ['3.0-10.0', '6.5', '5.7', '2.3'], 'units': []}, 'eGFR': {'values': ['88 83', 'between 60 and 89', '42:321'], 'units': ['CKD', 'microalbuminuria', 'proteinuria or haematuria', 'UMM']}, 'Urate': {'values': ['0.14-0.36', '13'], 'units': ['U/L', 'ALT', 'U/L', 'U/L 11']}, 'Alk Phos': {'values': ['68', '65', '36-48', '39'], 'units': ['U/L 65']}, 'Ca': {'values': ['2.10', '2.43', '2.41', '2.10', '2.51', '2.41', '2.45', '1.01', '1.24'], 'units': []}, 'CPK': {'values': [], 'units': ['U/L']}, 'Amylase': {'values': ['29'], 'units': ['U/L', 'U/L']}, 'Mg': {'values': ['0.70-1.10', '0.90'], 'units': []}, 'Prolactin': {'values': ['40-570', '121'], 'units': ['UMM']}, 'Erythrocytes': {'values': ['6', '2', '6'], 'units': ['UMM'] ...

# %%
# Function to add matcher patterns for units
def add_matcher_patterns(matcher):
    # Define the pattern for matching units
    pattern = [{"LOWER": {"IN": ["iu", "g", "mmol", "u"]}}, {"TEXT": "/"}, {"LOWER": {"IN": ["ml", "l"]}}]
    matcher.add("unit", [pattern])

# Initialize matcher with the shared vocab
matcher = Matcher(nlp.vocab)
add_matcher_patterns(matcher)

# %%
# Function to process units
def process_units(units):
    for unit in units:
        doc = nlp(unit)
        matches = matcher(doc)
        if matches:
            return unit  # Return the first matched unit
    return None  # Return None if no units match

# Function to determine if a string is a date
def is_date(string):
    return bool(re.match(r'\d{2}-\d{2}-\d{4}', string))

# Convert drug_data to the required format
output_data = {}
for drug, details in drug_data.items():
    # Filter out dates and get the last non-date value
    values = [v for v in details['values'] if not is_date(v)]
    last_value = values[-1] if values else None

    # Process units
    processed_unit = process_units(details['units'])

    # Store in new structure
    output_data[drug] = {
        "drug_name": drug,
        "value": last_value,
        "unit": processed_unit.split(" ")[0] if processed_unit else None
    }

# Save as JSON
json_output = json.dumps(output_data, indent=4)
print(json_output)

# Optionally, save to a file
with open('output_data.json', 'w') as json_file:
    json_file.write(json_output)
# Out:
# {
#     "PRL": {
#         "drug_name": "PRL",
#         "value": "125",
#         "unit": null
#     },
#     "Vitamin D": {
#         "drug_name": "Vitamin D",
#         "value": "196(11),686-687",
#         "unit": null
#     },
#     "Iron": {
#         "drug_name": "Iron",
#         "value": "27",
#         "unit": null
#     },
#     "T": {
#         "drug_name": "T",
#         "value": null,
#         "unit": null
#     },
#     "T. Sat.": {
#         "drug_name": "T. Sat.",
#         "value": null,
#         "unit": null
#     },
#     "Ferritin": {
#         "drug_name": "Ferritin",
#         "value": "between 50 and 100",
#         "unit": null
#     },
#     "Anti-Thyroglobulin Abs": {
#         "drug_name": "Anti-Thyroglobulin Abs",
#         "value": "110",
#         "unit": null
#     },
#     "Anti-Thyroidal Peroxidase Abs": {
#         "drug_name": "Anti-Thyroidal Peroxidase Abs",
#         "value": "332",
#         "unit": "U/mL"
#     },
#     "Tg": {
#         "drug_name": "Tg",
#         "value": null,
#         "unit": null
#     },
#     "B12": {
#         "drug_name": "B12",
#         "value": "128",
#         "unit": null
#     },
#     "Folate": {
#         "drug_name": "Folate",
#         "value": "between 4.5 and 9.0",
#         "unit": null
#     },
#     "Na": {
#         "drug_name": "Na",
#         "value": "138",
#         "unit": null
#     },
#     "K": {
#         "drug_name": "K",
#         "value": "3.8",
#         "unit": null
#     },
#     "Cl": {
#         "drug_name": "Cl",
#         "value": "10-20",
#         "unit": null
#     },
#     "Urea": {
#         "drug_name": "Urea",
#         "value": "2.3",
#         "unit": null
#     },
#     "eGFR": {
#         "drug_name": "eGFR",
#         "value": "42:321",
#         "unit": null
#     },
#     "Urate": {
#         "drug_name": "Urate",
#         "value": "13",
#         "unit": "U/L"
#     },
#     "Alk Phos": {
#         "drug_name": "Alk Phos",
#         "value": "39",
#         "unit": "U/L"
#     },
#     "Ca": {
#         "drug_name": "Ca",
#         "value": "1.24",
#         "unit": null
#     },
#     "CPK": {
#         "drug_name": "CPK",
#         "value": null,
#         "unit": "U/L"
#     },
#     "Amylase": {
#         "drug_name": "Amylase",
#         "value": "29",
#         "unit": "U/L"
#     },
#     "Mg": {
#         "drug_name": "Mg",
#         "value": "0.90",
#         "unit": null
#     },
#     "Prolactin": {
#         "drug_name": "Prolactin",
#         "value": "121",
#         "unit": null
#     },
#     "Erythrocytes": {
#         "drug_name": "Erythrocytes",
#         "value": "6",
#         "unit": null
#     },
#     "Hb": {
#         "drug_name": "Hb",
#         "value": "130",
#         "unit": null
#     },
#     "Hct": {
#         "drug_name": "Hct",
#         "value": "102",
#         "unit": null
#     },
#     "MCH": {
#         "drug_name": "MCH",
#         "value": "202",
#         "unit": null
#     }
# }
